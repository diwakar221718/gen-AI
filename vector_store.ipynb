# %%
import os
os.environ["GOOGLE_API_KEY"] = "AQ.Ab8RN6JV6EQ1oU_i4zTvvwxcitoqK0pzK0b-HnEEbiyt4hZDuw"

# %%
# !pip install -U langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 25.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.5.5
#     Uninstalling langchain-core-1.5.5:
#       Successfully uninstalled langchain-core-1.5.5
# ...

# %%
# !pip install -U langchain langchain-google-genai langchain-chroma pypdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.1/385.1 kB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 32.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 21.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 84.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 58.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.7/95.7 kB 5.8 MB/s eta 0:00:00
# ...

# %%
# !pip install -U langchain-chroma

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

#embedding model
embeddings = GoogleGenerativeAIEmbeddings(
    model="models/gemini-embedding-001"
)

# %%
#testing embeding models
text = "LangChain is used to build applications with large language models."

vector = embeddings.embed_query(text)

print("Embedding dimensions:", len(vector))
print(vector[:5])
# Out:
# Embedding dimensions: 3072
# [-0.0057662623, 0.025133392, 0.01650625, -0.06490519, -0.030052932]

# %% [markdown]
# ### working with vector store (chroma)

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_chroma import Chroma

# %%
## step 1->creating document object
from langchain_core.documents import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
## step->2 making vector store
vector_store = Chroma(
    embedding_function=embeddings,
    persist_directory="my_chroma_db",
    collection_name="sample"
)

# %%
## step->3 add document in vector store(after adding doc in vector store unique id asssign to every object)
vector_store.add_documents(documents=docs)
# Out:
# ['d097ddc7-1b20-4163-89cc-715dae2d251e',
#  '10cd935a-d9a6-4405-80bf-8d2524073277',
#  'f43e806a-e878-4126-beba-bada5225ae20',
#  'fc02dc0e-cd67-49b9-b5f1-2e57a022e009',
#  'fb299c9c-daaf-455d-95fa-a8efdc3b49cb']

# %%
##step->4 view document
vector_store.get(include=["embeddings","documents","metadatas"])
# Out:
# {'ids': ['34d73990-5d29-48a0-8958-ea4f4ec4440c',
#   'c9bbfc8c-1726-4c16-afa3-d32e7873c329',
#   'a03b60a9-53e4-42b4-b410-3d16fb6013d6',
#   '70125d01-865e-46cb-abe3-f22d7b5f8c57',
#   '3428386c-9e69-41b4-9a2e-90e2340846f9'],
#  'embeddings': array([[-0.00982054,  0.02545763,  0.02402782, ...,  0.01414876,
#          -0.01560954, -0.00266117],
#         [-0.01989721,  0.01092714,  0.01730603, ...,  0.00973945,
#          -0.0176257 , -0.00460104],
#         [-0.01358705, -0.00359449,  0.01163961, ...,  0.01149882,
#          -0.02098301,  0.00373549],
#         [-0.01261678, -0.00227585,  0.00470995, ..., -0.00144414,
#           0.00646786, -0.00529741],
#         [-0.01413488, -0.02750698,  0.01302837, ...,  0.00987475,
#          -0.00950909, -0.00272136]]),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
# ...

# %%
##step->5 earch in vector store
vector_store.similarity_search(
    query='Who among these are a bowler',
    k=2                                         #no. of similar object want
)
# Out:
# [Document(id='70125d01-865e-46cb-abe3-f22d7b5f8c57', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(id='fc02dc0e-cd67-49b9-b5f1-2e57a022e009', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.')]

# %%
#search with similarity score (along with similarity score )
vector_store.similarity_search_with_score(
    query='Who among these are a bowler',
    k=2
)
# Out:
# [(Document(id='70125d01-865e-46cb-abe3-f22d7b5f8c57', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.6391493082046509),
#  (Document(id='fc02dc0e-cd67-49b9-b5f1-2e57a022e009', metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.6391493082046509)]

# %%
# meta-data filtering
vector_store.similarity_search_with_score(
    query="MS Dhooni",
    filter={"team": "Chennai Super Kings"}
)
# Out:
# [(Document(id='a03b60a9-53e4-42b4-b410-3d16fb6013d6', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   0.6589195132255554),
#  (Document(id='f43e806a-e878-4126-beba-bada5225ae20', metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   0.6589195132255554),
#  (Document(id='3428386c-9e69-41b4-9a2e-90e2340846f9', metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   0.7977368235588074),
# ...

# %%
#update document
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='09a39dc6-3ba6-4ea7-927e-fdda591da5e4', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['34d73990-5d29-48a0-8958-ea4f4ec4440c',
#   'c9bbfc8c-1726-4c16-afa3-d32e7873c329',
#   'a03b60a9-53e4-42b4-b410-3d16fb6013d6',
#   '70125d01-865e-46cb-abe3-f22d7b5f8c57',
#   '3428386c-9e69-41b4-9a2e-90e2340846f9',
#   'd097ddc7-1b20-4163-89cc-715dae2d251e',
#   '10cd935a-d9a6-4405-80bf-8d2524073277',
#   'f43e806a-e878-4126-beba-bada5225ae20',
#   'fc02dc0e-cd67-49b9-b5f1-2e57a022e009',
#   'fb299c9c-daaf-455d-95fa-a8efdc3b49cb'],
#  'embeddings': array([[-0.00982054,  0.02545763,  0.02402782, ...,  0.01414876,
#          -0.01560954, -0.00266117],
#         [-0.01989721,  0.01092714,  0.01730603, ...,  0.00973945,
#          -0.0176257 , -0.00460104],
#         [-0.01358705, -0.00359449,  0.01163961, ...,  0.01149882,
#          -0.02098301,  0.00373549],
#         ...,
#         [-0.01358705, -0.00359449,  0.01163961, ...,  0.01149882,
#          -0.02098301,  0.00373549],
#         [-0.01261678, -0.00227585,  0.00470995, ..., -0.00144414,
# ...

# %%
# delete document
vector_store.delete(ids=['bd502249-0c43-4146-9f06-9e2202bb4bd3'])

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['34d73990-5d29-48a0-8958-ea4f4ec4440c',
#   'c9bbfc8c-1726-4c16-afa3-d32e7873c329',
#   'a03b60a9-53e4-42b4-b410-3d16fb6013d6',
#   '70125d01-865e-46cb-abe3-f22d7b5f8c57',
#   '3428386c-9e69-41b4-9a2e-90e2340846f9',
#   'd097ddc7-1b20-4163-89cc-715dae2d251e',
#   '10cd935a-d9a6-4405-80bf-8d2524073277',
#   'f43e806a-e878-4126-beba-bada5225ae20',
#   'fc02dc0e-cd67-49b9-b5f1-2e57a022e009',
#   'fb299c9c-daaf-455d-95fa-a8efdc3b49cb'],
#  'embeddings': array([[-0.00982054,  0.02545763,  0.02402782, ...,  0.01414876,
#          -0.01560954, -0.00266117],
#         [-0.01989721,  0.01092714,  0.01730603, ...,  0.00973945,
#          -0.0176257 , -0.00460104],
#         [-0.01358705, -0.00359449,  0.01163961, ...,  0.01149882,
#          -0.02098301,  0.00373549],
#         ...,
#         [-0.01358705, -0.00359449,  0.01163961, ...,  0.01149882,
#          -0.02098301,  0.00373549],
#         [-0.01261678, -0.00227585,  0.00470995, ..., -0.00144414,
# ...

# %%
# !git clone https://github.com/diwakar221718/gen-AI.git
# Out:
# Cloning into 'gen-AI'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 42 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 16.91 KiB | 8.46 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !ls -lah /content/gen-AI
# Out:
# total 24K
# drwxr-xr-x 5 root root 4.0K Aug 27 13:36 .
# drwxr-xr-x 1 root root 4.0K Aug 27 13:36 ..
# drwxr-xr-x 8 root root 4.0K Aug 27 13:36 .git
# drwxr-xr-x 2 root root 4.0K Aug 27 13:36 langchain_doc_loader
# drwxr-xr-x 2 root root 4.0K Aug 27 13:36 langchain_doc_splitter
# -rw-r--r-- 1 root root   61 Aug 27 13:36 README.md

# %%
# !find /content -name "vector_store.ipynb"
